# %%
import pandas as pd
import numpy as n
import math

# %%
config = {
  "worker" : {
    "min_storage_gb": 50,
    "extra": 3,
    "reserved_cpu": 2,
    "reserved_ram_gb": 4,
    "spare_resource_pct": 20
  }
}

# %%
pods = pd.read_csv(r"pods.csv")
vms = pd.read_csv(r"vms.csv")

# %%
for workload in [pods, vms]:
  workload['total_vcpu'] = workload['count'] * workload['vcpu']
  workload['total_ram_gb'] = workload['count'] * workload['ram_gb']
  workload['total_storage_gb'] = workload['count'] * (workload['estorage_gb'] + workload['pstorage_gb'])
  workload

# %% [markdown]
# # Pods

# %%
pods
# Out:
#       site    domain       env     host_profile               name  count  \
# 0   Site 1  Non-Prod       Dev  K8s-Worker-Apps           ACME API      1
# 1   Site 1  Non-Prod       Dev  K8s-Worker-Apps   ACME Backend API      1
# 2   Site 1  Non-Prod       Dev  K8s-Worker-Apps    Foo Account API      1
# 3   Site 1  Non-Prod       Dev  K8s-Worker-Apps       Foo Kong API      1
# 4   Site 1  Non-Prod       Dev  K8s-Worker-Apps        Foo SSO API      1
# 5   Site 1  Non-Prod       Dev  K8s-Worker-Apps        SMS Gateway      1
# 6   Site 1  Non-Prod       Dev   K8s-Worker-DB1      ACME Database      1
# 7   Site 1  Non-Prod       Dev   K8s-Worker-DB2       Foo Database      1
# 8   Site 1  Non-Prod       Dev    K8s-Worker-DS      ACME Eventbus      1
# 9   Site 1  Non-Prod       Dev    K8s-Worker-DS  Foo Elasticsearch      1
# 10  Site 1  Non-Prod       Dev    K8s-Worker-DS       Foo RabbitMQ      1
# 11  Site 1  Non-Prod       Dev    K8s-Worker-DS          Foo Redis      1
# 12  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps           ACME API      2
# 13  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps   ACME Backend API      2
# 14  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps    Foo Account API      2
# 15  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps       Foo Kong API      2
# 16  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps        Foo SSO API      2
# 17  Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps        SMS Gateway      2
# 18  Site 1  Non-Prod  Pre-Prod   K8s-Worker-DB1      ACME Database      3
# 19  Site 1  Non-Prod  Pre-Prod   K8s-Worker-DB2       Foo Database      3
# 20  Site 1  Non-Prod  Pre-Prod    K8s-Worker-DS      ACME Eventbus      3
# 21  Site 1  Non-Prod  Pre-Prod    K8s-Worker-DS  Foo Elasticsearch      3
# 22  Site 1  Non-Prod  Pre-Prod    K8s-Worker-DS       Foo RabbitMQ      3
# 23  Site 1  Non-Prod  Pre-Prod    K8s-Worker-DS          Foo Redis      3
# 24  Site 1  Non-Prod   Staging  K8s-Worker-Apps           ACME API      1
# 25  Site 1  Non-Prod   Staging  K8s-Worker-Apps   ACME Backend API      1
# 26  Site 1  Non-Prod   Staging  K8s-Worker-Apps    Foo Account API      1
# 27  Site 1  Non-Prod   Staging  K8s-Worker-Apps       Foo Kong API      1
# 28  Site 1  Non-Prod   Staging  K8s-Worker-Apps        Foo SSO API      1
# 29  Site 1  Non-Prod   Staging  K8s-Worker-Apps        SMS Gateway      1
# 30  Site 1  Non-Prod   Staging   K8s-Worker-DB1      ACME Database      1
# 31  Site 1  Non-Prod   Staging   K8s-Worker-DB2       Foo Database      1
# 32  Site 1  Non-Prod   Staging    K8s-Worker-DS      ACME Eventbus      1
# 33  Site 1  Non-Prod   Staging    K8s-Worker-DS  Foo Elasticsearch      1
# 34  Site 1  Non-Prod   Staging    K8s-Worker-DS       Foo RabbitMQ      1
# 35  Site 1  Non-Prod   Staging    K8s-Worker-DS          Foo Redis      1
# 36  Site 1      Prod      Prod  K8s-Worker-Apps           ACME API     20
# 37  Site 1      Prod      Prod  K8s-Worker-Apps   ACME Backend API     12
# 38  Site 1      Prod      Prod  K8s-Worker-Apps    Foo Account API     15
# 39  Site 1      Prod      Prod  K8s-Worker-Apps       Foo Kong API      3
# 40  Site 1      Prod      Prod  K8s-Worker-Apps        Foo SSO API     15
# 41  Site 1      Prod      Prod  K8s-Worker-Apps        SMS Gateway      5
# 42  Site 1      Prod      Prod   K8s-Worker-DB1      ACME Database      3
# 43  Site 1      Prod      Prod   K8s-Worker-DB2       Foo Database      3
# 44  Site 1      Prod      Prod    K8s-Worker-DS      ACME Eventbus      5
# 45  Site 1      Prod      Prod    K8s-Worker-DS  Foo Elasticsearch      3
# 46  Site 1      Prod      Prod    K8s-Worker-DS       Foo RabbitMQ      3
# 47  Site 1      Prod      Prod    K8s-Worker-DS          Foo Redis      3
# 48  Site 2        DR        DR  K8s-Worker-Apps           ACME API     20
# 49  Site 2        DR        DR  K8s-Worker-Apps   ACME Backend API     12
# 50  Site 2        DR        DR  K8s-Worker-Apps    Foo Account API     15
# 51  Site 2        DR        DR  K8s-Worker-Apps       Foo Kong API      3
# 52  Site 2        DR        DR  K8s-Worker-Apps        Foo SSO API     15
# 53  Site 2        DR        DR  K8s-Worker-Apps        SMS Gateway      5
# 54  Site 2        DR        DR   K8s-Worker-DB1      ACME Database      3
# 55  Site 2        DR        DR   K8s-Worker-DB2       Foo Database      3
# 56  Site 2        DR        DR    K8s-Worker-DS      ACME Eventbus      5
# 57  Site 2        DR        DR    K8s-Worker-DS  Foo Elasticsearch      3
# 58  Site 2        DR        DR    K8s-Worker-DS       Foo RabbitMQ      3
# 59  Site 2        DR        DR    K8s-Worker-DS          Foo Redis      3
#
#     vcpu  ram_gb  estorage_gb  pstorage_gb  total_vcpu  total_ram_gb  \
# 0      1       4            2           20           1             4
# 1      1       4            2           20           1             4
# 2      1       2            2           20           1             2
# 3      1       2            2           20           1             2
# 4      1       2            2           20           1             2
# 5      2       8            2           20           2             8
# 6      2       8            2           20           2             8
# 7      2       8            2           20           2             8
# 8      1       4            2           20           1             4
# 9      1       2            2           20           1             2
# 10     2       8            2           20           2             8
# 11     2       8            2           20           2             8
# 12     2       8            2           20           4            16
# 13     2       8            2           20           4            16
# 14     2       4            2           20           4             8
# 15     2       4            2           20           4             8
# 16     2       4            2           20           4             8
# 17     4      16            2           20           8            32
# 18     2       8            2           20           6            24
# 19     2       8            2           20           6            24
# 20     2       8            2           20           6            24
# 21     2       4            2           20           6            12
# 22     4      16            2           20          12            48
# 23     4      16            2           20          12            48
# 24     2       8            2           20           2             8
# 25     2       8            2           20           2             8
# 26     2       4            2           20           2             4
# 27     2       4            2           20           2             4
# 28     2       4            2           20           2             4
# 29     4      16            2           20           4            16
# 30     2       8            2           20           2             8
# 31     2       8            2           20           2             8
# 32     2       8            2           20           2             8
# 33     2       4            2           20           2             4
# 34     4      16            2           20           4            16
# 35     4      16            2           20           4            16
# 36     4      16            2          200          80           320
# 37     4      16            2          200          48           192
# 38     4      16            2          200          60           240
# 39     4      16            2          200          12            48
# 40     4      16            2          200          60           240
# 41     4      16            2          200          20            80
# 42    16      64            2         2000          48           192
# 43     8      16            2          200          24            48
# 44     4      16            2          200          20            80
# 45     4      16            2          200          12            48
# 46     4      16            2          200          12            48
# 47     4      16            2          200          12            48
# 48     4      16            2          200          80           320
# 49     4      16            2          200          48           192
# 50     4      16            2          200          60           240
# 51     4      16            2          200          12            48
# 52     4      16            2          200          60           240
# 53     4      16            2          200          20            80
# 54    16      64            2         2000          48           192
# 55     8      16            2          200          24            48
# 56     4      16            2          200          20            80
# 57     4      16            2          200          12            48
# 58     4      16            2          200          12            48
# 59     4      16            2          200          12            48
#
#     total_storage_gb
# 0                 22
# 1                 22
# 2                 22
# 3                 22
# 4                 22
# 5                 22
# 6                 22
# 7                 22
# 8                 22
# 9                 22
# 10                22
# 11                22
# 12                44
# 13                44
# 14                44
# 15                44
# 16                44
# 17                44
# 18                66
# 19                66
# 20                66
# 21                66
# 22                66
# 23                66
# 24                22
# 25                22
# 26                22
# 27                22
# 28                22
# 29                22
# 30                22
# 31                22
# 32                22
# 33                22
# 34                22
# 35                22
# 36              4040
# 37              2424
# 38              3030
# 39               606
# 40              3030
# 41              1010
# 42              6006
# 43               606
# 44              1010
# 45               606
# 46               606
# 47               606
# 48              4040
# 49              2424
# 50              3030
# 51               606
# 52              3030
# 53              1010
# 54              6006
# 55               606
# 56              1010
# 57               606
# 58               606
# 59               606

# %% [markdown]
# # Static Virtual Machines

# %%
vms
# Out:
#       site    domain             env      host_profile              name  \
# 0   Site 2        DR      Management             Other             Other
# 1   Site 2        DR      Management               NSX    NSX Controller
# 2   Site 2        DR           Infra              vRPA        vRPA Addtl
# 3   Site 2        DR           Infra               NSX          NSX-Edge
# 4   Site 2        DR              DR        K8s-Master        K8s-Master
# 5   Site 2        DR    DR-Reporting  Reporting Server  Reporting Server
# 6   Site 1      Prod            Prod        K8s-Master        K8s-Master
# 7   Site 1      Prod  Prod-Reporting  Reporting Server  Reporting Server
# 8   Site 1      Prod           Infra              vRPA        vRPA Addtl
# 9   Site 1      Prod           Infra               NSX          NSX-Edge
# 10  Site 1  Non-Prod         Staging  Reporting Server  Reporting Server
# 11  Site 1  Non-Prod         Staging        K8s-Master        K8s-Master
# 12  Site 1  Non-Prod        Pre-Prod  Reporting Server  Reporting Server
# 13  Site 1  Non-Prod        Pre-Prod        K8s-Master        K8s-Master
# 14  Site 1  Non-Prod      Management             Other             Other
# 15  Site 1  Non-Prod      Management               NSX    NSX Controller
# 16  Site 1  Non-Prod           Infra               NSX          NSX-Edge
# 17  Site 1  Non-Prod             Dev  Reporting Server  Reporting Server
# 18  Site 1  Non-Prod             Dev        K8s-Master        K8s-Master
#
#     count  vcpu  ram_gb  estorage_gb  pstorage_gb  total_vcpu  total_ram_gb  \
# 0      15     6      18            0          256          90           270
# 1       8     8      32            0          200          64           256
# 2       2     8      32            0           35          16            64
# 3       2    16      64           50          200          32           128
# 4       3     4      16            2          200          12            48
# 5       1     8      64           20          600           8            64
# 6       3     4      16            2           50          12            48
# 7       1     8      64           20          600           8            64
# 8       2     8      32            0           35          16            64
# 9       2    16      64           50          200          32           128
# 10      1     2      16           20           20           2            16
# 11      3     4      16            2           50          12            48
# 12      1     2      16           20           20           2            16
# 13      3     4      16            2           50          12            48
# 14     15     6      18            0          256          90           270
# 15      8     8      32            0          200          64           256
# 16      2    16      64           50          200          32           128
# 17      1     2      16           20           20           2            16
# 18      3     4      16            2           50          12            48
#
#     total_storage_gb
# 0               3840
# 1               1600
# 2                 70
# 3                500
# 4                606
# 5                620
# 6                156
# 7                620
# 8                 70
# 9                500
# 10                40
# 11               156
# 12                40
# 13               156
# 14              3840
# 15              1600
# 16               500
# 17                40
# 18               156

# %%
pod_summary = pods.groupby(["site", "domain", "env", "host_profile"])
workers = []
worker_spare_resource = 1 + config["worker"]["spare_resource_pct"]/100
for name, group in pod_summary:
   site = name[0]
   domain = name[1]
   env = name[2]
   host_profile = name[3]
   worker_name = name[3]
   
   
   pod_group = group.sum()   

   pods_per_worker = math.floor(math.sqrt(pod_group['count']))
  #  worker_name = worker_name + " PPW(" + str(pods_per_worker) + ")"

   min_workers = math.ceil(pod_group['count']/pods_per_worker)
   
   # 2 vcpu for system service, 1.2 time (or 20% extra) for spare capacity
   workload_cpu = pod_group['total_vcpu']/min_workers
   min_worker_cpu = math.ceil( ( workload_cpu + config["worker"]["reserved_cpu"] ) * worker_spare_resource)
   
   # 4 gb for system service, 1.2 time (or 20% extra) for spare capacity
   workload_ram = pod_group['total_ram_gb']/min_workers
   min_worker_ram = math.ceil( ( workload_ram + config["worker"]["reserved_ram_gb"] ) * worker_spare_resource )

   min_worker_estorage = config["worker"]["min_storage_gb"]
   min_worker_pstorage = pod_group['total_storage_gb']/min_workers
   
   worker_count = min_workers + config["worker"]["extra"]
   worker_vcpu = min_worker_cpu
   worker_ram_gb = min_worker_ram
   worker_estorage_gb = math.ceil(min_worker_estorage)
   worker_pstorage_gb = math.ceil(min_worker_pstorage)
   total_worker_vcpu = worker_count * worker_vcpu
   total_worker_ram_gb = worker_count * worker_ram_gb
   total_worker_storage_gb = worker_count * (worker_estorage_gb + worker_pstorage_gb)

   workers.append([site,domain,env,host_profile, worker_name, worker_count, worker_vcpu, worker_ram_gb, worker_estorage_gb, worker_pstorage_gb, total_worker_vcpu, total_worker_ram_gb, total_worker_storage_gb])

# %% [markdown]
# # Kubernetes Workers

# %%
workers_df = pd.DataFrame(data=workers, columns=vms.columns)
workers_df
# Out:
#       site    domain       env     host_profile             name  count  vcpu  \
# 0   Site 1  Non-Prod       Dev  K8s-Worker-Apps  K8s-Worker-Apps      6     6
# 1   Site 1  Non-Prod       Dev   K8s-Worker-DB1   K8s-Worker-DB1      4     5
# 2   Site 1  Non-Prod       Dev   K8s-Worker-DB2   K8s-Worker-DB2      4     5
# 3   Site 1  Non-Prod       Dev    K8s-Worker-DS    K8s-Worker-DS      5     6
# 4   Site 1  Non-Prod  Pre-Prod  K8s-Worker-Apps  K8s-Worker-Apps      7    11
# 5   Site 1  Non-Prod  Pre-Prod   K8s-Worker-DB1   K8s-Worker-DB1      6     5
# 6   Site 1  Non-Prod  Pre-Prod   K8s-Worker-DB2   K8s-Worker-DB2      6     5
# 7   Site 1  Non-Prod  Pre-Prod    K8s-Worker-DS    K8s-Worker-DS      7    14
# 8   Site 1  Non-Prod   Staging  K8s-Worker-Apps  K8s-Worker-Apps      6     8
# 9   Site 1  Non-Prod   Staging   K8s-Worker-DB1   K8s-Worker-DB1      4     5
# 10  Site 1  Non-Prod   Staging   K8s-Worker-DB2   K8s-Worker-DB2      4     5
# 11  Site 1  Non-Prod   Staging    K8s-Worker-DS    K8s-Worker-DS      5    10
# 12  Site 1      Prod      Prod  K8s-Worker-Apps  K8s-Worker-Apps     12    40
# 13  Site 1      Prod      Prod   K8s-Worker-DB1   K8s-Worker-DB1      6    22
# 14  Site 1      Prod      Prod   K8s-Worker-DB2   K8s-Worker-DB2      6    12
# 15  Site 1      Prod      Prod    K8s-Worker-DS    K8s-Worker-DS      8    16
# 16  Site 2        DR        DR  K8s-Worker-Apps  K8s-Worker-Apps     12    40
# 17  Site 2        DR        DR   K8s-Worker-DB1   K8s-Worker-DB1      6    22
# 18  Site 2        DR        DR   K8s-Worker-DB2   K8s-Worker-DB2      6    12
# 19  Site 2        DR        DR    K8s-Worker-DS    K8s-Worker-DS      8    16
#
#     ram_gb  estorage_gb  pstorage_gb  total_vcpu  total_ram_gb  \
# 0       14           50           44          36            84
# 1       15           50           22          20            60
# 2       15           50           22          20            60
# 3       18           50           44          30            90
# 4       32           50           66          77           224
# 5       15           50           22          30            90
# 6       15           50           22          30            90
# 7       45           50           66          98           315
# 8       23           50           44          48           138
# 9       15           50           22          20            60
# 10      15           50           22          20            60
# 11      32           50           44          50           160
# 12     155           50         1572         480          1860
# 13      82           50         2002         132           492
# 14      24           50          202          72           144
# 15      59           50          566         128           472
# 16     155           50         1572         480          1860
# 17      82           50         2002         132           492
# 18      24           50          202          72           144
# 19      59           50          566         128           472
#
#     total_storage_gb
# 0                564
# 1                288
# 2                288
# 3                470
# 4                812
# 5                432
# 6                432
# 7                812
# 8                564
# 9                288
# 10               288
# 11               470
# 12             19464
# 13             12312
# 14              1512
# 15              4928
# 16             19464
# 17             12312
# 18              1512
# 19              4928

# %% [markdown]
# # Virtual Infrastructure Detailed

# %%
site = vms.append(workers_df).sort_values(["site","domain", "env", "host_profile", "name"])
site
# Out:
#       site    domain             env      host_profile              name  \
# 18  Site 1  Non-Prod             Dev        K8s-Master        K8s-Master
# 0   Site 1  Non-Prod             Dev   K8s-Worker-Apps   K8s-Worker-Apps
# 1   Site 1  Non-Prod             Dev    K8s-Worker-DB1    K8s-Worker-DB1
# 2   Site 1  Non-Prod             Dev    K8s-Worker-DB2    K8s-Worker-DB2
# 3   Site 1  Non-Prod             Dev     K8s-Worker-DS     K8s-Worker-DS
# 17  Site 1  Non-Prod             Dev  Reporting Server  Reporting Server
# 16  Site 1  Non-Prod           Infra               NSX          NSX-Edge
# 15  Site 1  Non-Prod      Management               NSX    NSX Controller
# 14  Site 1  Non-Prod      Management             Other             Other
# 13  Site 1  Non-Prod        Pre-Prod        K8s-Master        K8s-Master
# 4   Site 1  Non-Prod        Pre-Prod   K8s-Worker-Apps   K8s-Worker-Apps
# 5   Site 1  Non-Prod        Pre-Prod    K8s-Worker-DB1    K8s-Worker-DB1
# 6   Site 1  Non-Prod        Pre-Prod    K8s-Worker-DB2    K8s-Worker-DB2
# 7   Site 1  Non-Prod        Pre-Prod     K8s-Worker-DS     K8s-Worker-DS
# 12  Site 1  Non-Prod        Pre-Prod  Reporting Server  Reporting Server
# 11  Site 1  Non-Prod         Staging        K8s-Master        K8s-Master
# 8   Site 1  Non-Prod         Staging   K8s-Worker-Apps   K8s-Worker-Apps
# 9   Site 1  Non-Prod         Staging    K8s-Worker-DB1    K8s-Worker-DB1
# 10  Site 1  Non-Prod         Staging    K8s-Worker-DB2    K8s-Worker-DB2
# 11  Site 1  Non-Prod         Staging     K8s-Worker-DS     K8s-Worker-DS
# 10  Site 1  Non-Prod         Staging  Reporting Server  Reporting Server
# 9   Site 1      Prod           Infra               NSX          NSX-Edge
# 8   Site 1      Prod           Infra              vRPA        vRPA Addtl
# 6   Site 1      Prod            Prod        K8s-Master        K8s-Master
# 12  Site 1      Prod            Prod   K8s-Worker-Apps   K8s-Worker-Apps
# 13  Site 1      Prod            Prod    K8s-Worker-DB1    K8s-Worker-DB1
# 14  Site 1      Prod            Prod    K8s-Worker-DB2    K8s-Worker-DB2
# 15  Site 1      Prod            Prod     K8s-Worker-DS     K8s-Worker-DS
# 7   Site 1      Prod  Prod-Reporting  Reporting Server  Reporting Server
# 4   Site 2        DR              DR        K8s-Master        K8s-Master
# 16  Site 2        DR              DR   K8s-Worker-Apps   K8s-Worker-Apps
# 17  Site 2        DR              DR    K8s-Worker-DB1    K8s-Worker-DB1
# 18  Site 2        DR              DR    K8s-Worker-DB2    K8s-Worker-DB2
# 19  Site 2        DR              DR     K8s-Worker-DS     K8s-Worker-DS
# 5   Site 2        DR    DR-Reporting  Reporting Server  Reporting Server
# 3   Site 2        DR           Infra               NSX          NSX-Edge
# 2   Site 2        DR           Infra              vRPA        vRPA Addtl
# 1   Site 2        DR      Management               NSX    NSX Controller
# 0   Site 2        DR      Management             Other             Other
#
#     count  vcpu  ram_gb  estorage_gb  pstorage_gb  total_vcpu  total_ram_gb  \
# 18      3     4      16            2           50          12            48
# 0       6     6      14           50           44          36            84
# 1       4     5      15           50           22          20            60
# 2       4     5      15           50           22          20            60
# 3       5     6      18           50           44          30            90
# 17      1     2      16           20           20           2            16
# 16      2    16      64           50          200          32           128
# 15      8     8      32            0          200          64           256
# 14     15     6      18            0          256          90           270
# 13      3     4      16            2           50          12            48
# 4       7    11      32           50           66          77           224
# 5       6     5      15           50           22          30            90
# 6       6     5      15           50           22          30            90
# 7       7    14      45           50           66          98           315
# 12      1     2      16           20           20           2            16
# 11      3     4      16            2           50          12            48
# 8       6     8      23           50           44          48           138
# 9       4     5      15           50           22          20            60
# 10      4     5      15           50           22          20            60
# 11      5    10      32           50           44          50           160
# 10      1     2      16           20           20           2            16
# 9       2    16      64           50          200          32           128
# 8       2     8      32            0           35          16            64
# 6       3     4      16            2           50          12            48
# 12     12    40     155           50         1572         480          1860
# 13      6    22      82           50         2002         132           492
# 14      6    12      24           50          202          72           144
# 15      8    16      59           50          566         128           472
# 7       1     8      64           20          600           8            64
# 4       3     4      16            2          200          12            48
# 16     12    40     155           50         1572         480          1860
# 17      6    22      82           50         2002         132           492
# 18      6    12      24           50          202          72           144
# 19      8    16      59           50          566         128           472
# 5       1     8      64           20          600           8            64
# 3       2    16      64           50          200          32           128
# 2       2     8      32            0           35          16            64
# 1       8     8      32            0          200          64           256
# 0      15     6      18            0          256          90           270
#
#     total_storage_gb
# 18               156
# 0                564
# 1                288
# 2                288
# 3                470
# 17                40
# 16               500
# 15              1600
# 14              3840
# 13               156
# 4                812
# 5                432
# 6                432
# 7                812
# 12                40
# 11               156
# 8                564
# 9                288
# 10               288
# 11               470
# 10                40
# 9                500
# 8                 70
# 6                156
# 12             19464
# 13             12312
# 14              1512
# 15              4928
# 7                620
# 4                606
# 16             19464
# 17             12312
# 18              1512
# 19              4928
# 5                620
# 3                500
# 2                 70
# 1               1600
# 0               3840

# %% [markdown]
# # Total Virtual Infrastructure Footprint By Site By Environment

# %%
site.groupby(["site","domain"]).sum()
# Out:
#                  count  vcpu  ram_gb  estorage_gb  pstorage_gb  total_vcpu  \
# site   domain
# Site 1 Non-Prod    101   133     464          716         1306         707
#        Prod         40   126     496          272         5227         880
# Site 2 DR           63   140     546          272         5833        1034
#
#                  total_ram_gb  total_storage_gb
# site   domain
# Site 1 Non-Prod          2277             12236
#        Prod              3272             39562
# Site 2 DR                3798             45452
